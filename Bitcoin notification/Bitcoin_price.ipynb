# %%
import requests
>>> bitcoin_api_url = 'https://api.coinmarketcap.com/v1/ticker/bitcoin/'
>>> response = requests.get(bitcoin_api_url)
>>> response_json = response.json()
>>> type(response_json) # The API returns a list
>>> # Bitcoin data is the first element of the list
>>> response_json[0]
# Out:
# {'id': 'bitcoin',
#  'name': 'Bitcoin',
#  'symbol': 'BTC',
#  'rank': '1',
#  'price_usd': '3467.13945467',
#  'price_btc': '1.0',
#  '24h_volume_usd': '5342161882.61',
#  'market_cap_usd': '60745451672.0',
#  'available_supply': '17520337.0',
#  'total_supply': '17520337.0',
#  'max_supply': '21000000.0',
#  'percent_change_1h': '0.15',
#  'percent_change_24h': '0.13',
#  'percent_change_7d': '1.03',
#  'last_updated': '1549358965'}
